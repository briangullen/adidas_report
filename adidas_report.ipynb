# %%
import pandas as pd
import seaborn as sns

# %%
adidas_df = pd.read_excel('Adidas US Sales Datasets.xlsx', skiprows=4)

# %%
adidas_df = adidas_df.drop(columns='Unnamed: 0')

# %%
adidas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
adidas_df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              0.50     In-store
# ...

# %%
adidas_df['Product'].unique()
# Out:
# array(["Men's Street Footwear", "Men's Athletic Footwear",
#        "Women's Street Footwear", "Women's Athletic Footwear",
#        "Men's Apparel", "Women's Apparel"], dtype=object)

# %%
adidas_df['Region'].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast'], dtype=object)

# %%
adidas_df['Sales Method'].unique()
# Out:
# array(['In-store', 'Outlet', 'Online'], dtype=object)

# %%
adidas_df['Retailer'].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
sns.countplot(data=adidas_df, x='Region').set(title='Total Sales by Region')
# Out:
# [Text(0.5, 1.0, 'Total Sales by Region')]

# %%
sns.relplot(data=adidas_df, x='Price per Unit', y='Operating Profit', hue='Sales Method').set(title='Operating Profit Compared with Pricer per Unit')

# %%
sns.countplot(data=adidas_df, x='Sales Method', stat='percent').set(title='Percent of Sales by Method')
# Out:
# [Text(0.5, 1.0, 'Percent of Sales by Method')]

# %%
ax = sns.barplot(data=adidas_df, x='Product', y='Units Sold')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40)
ax.set(title='Units Sold by Product')
# Out:
# /var/folders/bn/r234zn0d75qf_wgd0b0mw7s00000gn/T/ipykernel_1579/3343113133.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40)
# [Text(0.5, 1.0, 'Units Sold by Product')]

# %%
sns.boxplot(data=adidas_df, x='Retailer', y='Units Sold')
# Out:
# <Axes: xlabel='Retailer', ylabel='Units Sold'>

# %%
sns.barplot(data=adidas_df, x='Retailer', y='Total Sales', hue='Region')
# Out:
# <Axes: xlabel='Retailer', ylabel='Total Sales'>
